# %%
from sklearn.datasets import load_boston

# %%
boston = load_boston()

# %%
boston.data.shape
# Out:
# (506, 13)

# %%
boston.feature_names
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'],
#       dtype='<U7')

# %%
from sklearn.neighbors import KNeighborsRegressor as knr
from sklearn.model_selection import train_test_split

K = 2
knn = knr(n_neighbors = K)
knn.fit(boston.data, boston.target)
print(boston.target[0])
print(knn.predict([boston.data[0]]))
# Out:
# 24.0
# [ 22.05]

# %%
y_ = knn.fit(boston.data, boston.target).predict([boston.data[12]])
print(y_)
print(boston.target[12])
# Out:
# [ 22.4]
# 21.7

# %%
import matplotlib.pyplot as plt
import numpy as np

knn = knr(n_neighbors=K)
x,y=boston.data[:50],boston.target[:50]
y__ = knn.fit(x,y).predict(x)
plt.plot(np.linspace(-1,1,50),y,label='data',color='black')
plt.plot(np.linspace(-1,1,50),y__,label='prediction',color='blue')
plt.legend()
plt.show()
